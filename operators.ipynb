# %% [markdown]
# Assignment Operators

# %%
a = 3
b = 3
sum = a + b
print(sum)
print(a/b)
print(a*b)
print(a//b)
print(a**b)
# Out:
# 6
# 1.0
# 9
# 1
# 27

# %%
a += 5
print(a)
# Out:
# 10

# %%
list = [24,34,53,5]
print(24 in list)
# Out:
# True

# %% [markdown]
# Dictionaries

# %%
dict = {
    "name": "yash",
    "age" : 45,
    "city" : "lucknow"
}
print(dict)
type(dict)
# Out:
# {'name': 'yash', 'age': 45, 'city': 'lucknow'}
# dict

# %% [markdown]
# Typecasting - Implicit and explicit
#
# -input() - takes string as an argument

# %%
a = input("Enter a number: ")
b = input("Enter another number: ")
x = int(a) + int(b) 
print(x)
# Out:
# 100

# %%
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))
print(x)
# Out:
# 100

# %% [markdown]
# fstring - placeholder for values

# %%
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))
print(f'The sum of {a} and {b} is {a+b}')
# Out:
# The sum of 65 and 56 is 121
